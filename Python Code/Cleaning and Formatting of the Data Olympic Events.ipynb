# %%
import pandas as pd
import numpy as np

# %%
#importing orginal dataset with all results
sports_events=pd.read_csv('/Users/alexandergandji/Desktop/Course Folder/Capstone Project SQL Data Science /Sports/SportsStats 2/athlete_events.csv')

# %%
sports_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# ### Nationality

# %%
#importing orginal dataset
nat=pd.read_csv('/Users/alexandergandji/Desktop/Course Folder/Capstone Project SQL Data Science /Sports/SportsStats 2/noc_regions.csv')

# %%
#creating a dataframe for all particpating nations
nat_df1=pd.DataFrame(nat, columns=['NOC'])
nat_df1=nat_df1.append({'NOC':'SGP'}, ignore_index=True)

# %%
#alocating a unique number to every value
nat_df1['NOC_ID']=range(1,232)

# %%
#setting a new index
nat_df1=nat_df1.set_index('NOC_ID')

# %%
nat_df1
# Out:
#         NOC
# NOC_ID
# 1       AFG
# 2       AHO
# 3       ALB
# 4       ALG
# 5       AND
# ...     ...
# 227     YMD
# 228     YUG
# 229     ZAM
# 230     ZIM
# 231     SGP
#
# [231 rows x 1 columns]

# %%
#saving it on a csv file
nat_df1.to_csv('/Users/alexandergandji/Desktop/Course Folder/Capstone Project SQL Data Science /Sports/nationality.csv')

# %% [markdown]
# ### Medal

# %%
sports_events
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#creating a new dataframe with the different medal types
medal_df=pd.DataFrame(sports_events.Medal.unique().tolist(), columns=['Medal'])

# %%
#Nan is considered as not winning a medal, I have transformed it to 'No_Medal'
medal_df=medal_df.fillna('No_Medal')

# %%
medal_df
# Out:
#       Medal
# 0  No_Medal
# 1      Gold
# 2    Bronze
# 3    Silver

# %%
#using lambda to allocate a number to each medal type
medal_df['Medal_ID']=medal_df['Medal'].apply(lambda x: 1 if x=='Gold' else (2 if x=='Silver' else
                                                                            (3 if x=='Bronze' else 4)))

# %%
medal_df
# Out:
#       Medal  Medal_ID
# 0  No_Medal         4
# 1      Gold         1
# 2    Bronze         3
# 3    Silver         2

# %%
#sorting values
medal_df.sort_values('Medal_ID', inplace=True)

# %%
#setting a new index
medal_df.set_index('Medal_ID', inplace=True)

# %%
#saving it on a csv file
medal_df.to_csv('/Users/alexandergandji/Desktop/Course Folder/Capstone Project SQL Data Science /Sports/olympic_medal.csv')

# %% [markdown]
# ### olympic games

# %%
sports_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
#using existing dataframe and formate it so no duplicates remain and every olympic game appears once
games=sports_events[['Games', 'Year', 'Season', 'City']].drop_duplicates()

# %%
#sorting values based on Games
games.sort_values('Games', inplace=True)

# %%
#using lambda to allocate to summer and winter games an unique number/ID
games['Season_ID']=games['Season'].apply(lambda x: 1 if x=='Summer' else 2)

# %%
len(games.Games)
# Out:
# 52

# %%
#allocating every game an unique number/ID
games['Games_ID']=range(1,53)

# %%
#droping column 'Season', this could have also been done with reindex()
games.drop('Season',1, inplace=True)
# Out:
# /var/folders/06/r72gs4510ldd1g4t75zm78vc0000gn/T/ipykernel_4326/2062314925.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   games.drop('Season',1, inplace=True)

# %%
games.head()
# Out:
#             Games  Year       City  Season_ID  Games_ID
# 3079  1896 Summer  1896     Athina          1         1
# 3     1900 Summer  1900      Paris          1         2
# 711   1904 Summer  1904  St. Louis          1         3
# 268   1906 Summer  1906     Athina          1         4
# 1149  1908 Summer  1908     London          1         5

# %%
#reindexing the columns
games_df=games.reindex(columns=['Games', 'Games_ID', 'Year', 'Season_ID', 'City'])

# %%
#setting a new index
games_df.set_index('Games_ID', inplace=True)

# %%
#saving it on a csv file
games_df.to_csv('/Users/alexandergandji/Desktop/Course Folder/Capstone Project SQL Data Science /Sports/olympic_games.csv')

# %% [markdown]
# ### athletes

# %%
sports_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
#getting an unique list of athletes
athlete=sports_events.Name.unique().tolist()

# %%
#creating a new dataframe
athlete=pd.DataFrame(athlete, columns=['Name'])

# %%
#sorting dataframe by name in ascending order
athlete.sort_values('Name', inplace=True)

# %%
#removing the extra space
athlete.replace('  Gabrielle Marie "Gabby" Adcock (White-)', 'Gabrielle Marie "Gabby" Adcock (White-)',
                inplace=True)
athlete.replace(' Eleonora Margarida Josephina Scmitt', 'Eleonora Margarida Josephina Scmitt', inplace=True)
athlete.replace(' Jean Hauptmanns', 'Jean Hauptmanns', inplace=True)
athlete.replace(' Luis ngel Fernando de los Santos Grossi', 'Luis ngel Fernando de los Santos Grossi', inplace=True)
athlete.replace(' Th Anh', 'Th Anh', inplace=True)
athlete.replace(' Th Ngn Thng', 'Th Ngn Thng', inplace=True)
athlete.replace(' Tin Tun', 'Tin Tun', inplace=True)
athlete.sort_values('Name', inplace=True)

# %%
#allocating an unique number/ID to every athlete and merging the dataframe with the orginal data to get the gender
athlete['Athlete_ID']=range(1,134788)
athlete=athlete.merge(sports_events[['Name', 'Sex']], how='left').drop_duplicates()

# %%
#using lambda to allocate an unique number to every gender
athlete['Sex_ID']=athlete.Sex.apply(lambda x: 1 if x=='M' else 2)

# %%
#setting a new index
athlete.set_index('Athlete_ID', inplace=True)

# %%
ath1=athlete.dropna()

# %%
#saving it on a csv file
ath1.to_csv('/Users/alexandergandji/Desktop/Course Folder/Capstone Project SQL Data Science /Sports/athlete.csv')

# %% [markdown]
# ### Sports

# %%
sports_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
#creating a new dataframe for every sport event
sports=pd.DataFrame(sports_events.Event.unique().tolist(), columns=['Sport'])

# %%
#sorting data by sport events
sports.sort_values('Sport', inplace=True)

# %%
sports
# Out:
#                                               Sport
# 764                   Aeronautics Mixed Aeronautics
# 34                     Alpine Skiing Men's Combined
# 30                     Alpine Skiing Men's Downhill
# 32                 Alpine Skiing Men's Giant Slalom
# 33                       Alpine Skiing Men's Slalom
# ..                                              ...
# 596          Wrestling Women's Flyweight, Freestyle
# 340        Wrestling Women's Heavyweight, Freestyle
# 292  Wrestling Women's Light-Heavyweight, Freestyle
# 356        Wrestling Women's Lightweight, Freestyle
# 609       Wrestling Women's Middleweight, Freestyle
#
# [765 rows x 1 columns]

# %%
#allocating an unique ID to every sport event
sport=sports['Sport_ID']=range(1,766)

# %%
#setting a new index
sports.set_index('Sport_ID', inplace=True)

# %%
sports
# Out:
#                                                    Sport
# Sport_ID
# 1                          Aeronautics Mixed Aeronautics
# 2                           Alpine Skiing Men's Combined
# 3                           Alpine Skiing Men's Downhill
# 4                       Alpine Skiing Men's Giant Slalom
# 5                             Alpine Skiing Men's Slalom
# ...                                                  ...
# 761               Wrestling Women's Flyweight, Freestyle
# 762             Wrestling Women's Heavyweight, Freestyle
# 763       Wrestling Women's Light-Heavyweight, Freestyle
# 764             Wrestling Women's Lightweight, Freestyle
# 765            Wrestling Women's Middleweight, Freestyle
#
# [765 rows x 1 columns]

# %%
#saving it on a csv file
sports.to_csv('/Users/alexandergandji/Desktop/Course Folder/Capstone Project SQL Data Science /Sports/sports.csv')

# %% [markdown]
# ### results

# %%
#merging orginal data with the nations dataframe
results1=sports_events.merge(nat_df1.reset_index(), how='left')

# %%
#adding a new column, which contains the medal id; using lambda
results1['Medal_ID']=results1.Medal.apply(lambda x: 1 if x=='Gold' else
                                          (2 if x=='Silver' else (3 if x=='Bronze' else 4)))

# %%
#removing extra space from athletes name
results1.replace('  Gabrielle Marie "Gabby" Adcock (White-)', 'Gabrielle Marie "Gabby" Adcock (White-)',
                 inplace=True)
results1.replace(' Eleonora Margarida Josephina Scmitt', 'Eleonora Margarida Josephina Scmitt', inplace=True)
results1.replace(' Jean Hauptmanns', 'Jean Hauptmanns', inplace=True)
results1.replace(' Luis ngel Fernando de los Santos Grossi', 'Luis ngel Fernando de los Santos Grossi',
                 inplace=True)
results1.replace(' Th Anh', 'Th Anh', inplace=True)
results1.replace(' Th Ngn Thng', 'Th Ngn Thng', inplace=True)
results1.replace(' Tin Tun', 'Tin Tun', inplace=True)

# %%
#merging results dataframe with the games dataframe
results2=results1.merge(games_df.reset_index(), how='left')

# %%
#merging results dataframe with the athlete dataframe
results3=results2.merge(athlete.reset_index(), how='left')

# %%
#dropping 'Sport' column=> this column just gave an general overview of the events
results3.drop('Sport',1,inplace=True)
# Out:
# /var/folders/06/r72gs4510ldd1g4t75zm78vc0000gn/T/ipykernel_4326/93642161.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   results3.drop('Sport',1,inplace=True)

# %%
#renaming Event to Sport=> the new Sport column has a more detailed overview of the different events
results3.rename(columns={'Event':'Sport'}, inplace=True)

# %%
#merging results dataframe with sports dataframe 
results4=results3.merge(sports.reset_index(), how='left')

# %%
#sort result dataframe by Year
results4.sort_values('Year', inplace=True)

# %%
results4
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 68791    35094            Angelos Fetsis   M   NaN     NaN     NaN
# 204735  102806             Richard Rstel   M   NaN     NaN     NaN
# 181753   91353  Georgios Paraskevopoulos   M   NaN     NaN     NaN
# 181754   91353  Georgios Paraskevopoulos   M   NaN     NaN     NaN
# 204736  102806             Richard Rstel   M   NaN     NaN     NaN
# ...        ...                       ...  ..   ...     ...     ...
# 40051    20599         Phillip Hung Chew   M  22.0   173.0    91.0
# 194190   97481               Bence Pulai   M  24.0   193.0    89.0
# 194191   97481               Bence Pulai   M  24.0   193.0    89.0
# 40081    20616                Danny Chia   M  43.0   170.0    75.0
# 245289  122828       Nigora Tursunkulova   F  17.0   181.0    67.0
#
#                  Team  NOC        Games  Year  ...            City  \
# 68791          Greece  GRE  1896 Summer  1896  ...          Athina
# ...

# %%
#due to the fact that we have data points which did not have any value in the Age, Height and Weight column we have
#used ffill()
results4['Age']=results4.Age.ffill(axis=0)
#applying ffill() in the first row of the Age column
results4.Age.replace(results4.Age.iloc[0],21, inplace=True)
#transforming Age from float to integer
results4['Age']=results4.Age.apply(np.int64)

# %%
results4=results4.copy()

# %%
#applying ffill() in the first row of the Height column
results4['Height']=results4.Height.replace(results4.Height.iloc[0],176)
#transforming Height from float to integer
results4['Height']=results4.Height.apply(np.int64)

### 176 was chosen, because the height was found at other athletes in the same time period and disceplines

# %%
results4
# Out:
#             ID                      Name Sex  Age  Height  Weight  \
# 68791    35094            Angelos Fetsis   M   21     176     NaN
# 204735  102806             Richard Rstel   M   21     176     NaN
# 181753   91353  Georgios Paraskevopoulos   M   21     176     NaN
# 181754   91353  Georgios Paraskevopoulos   M   21     176     NaN
# 204736  102806             Richard Rstel   M   21     176     NaN
# ...        ...                       ...  ..  ...     ...     ...
# 40051    20599         Phillip Hung Chew   M   22     173    91.0
# 194190   97481               Bence Pulai   M   24     193    89.0
# 194191   97481               Bence Pulai   M   24     193    89.0
# 40081    20616                Danny Chia   M   43     170    75.0
# 245289  122828       Nigora Tursunkulova   F   17     181    67.0
#
#                  Team  NOC        Games  Year  ...            City  \
# 68791          Greece  GRE  1896 Summer  1896  ...          Athina
# ...

# %%
x=round((66+66+69)/3,0)
print(x)
### These 3 values are representive for the weight in the early time period, early 20th century, and discepliens
# Out:
# 67.0

# %%
#applying ffill() in the first row of the Weight column
results4['Weight']=results4.Weight.replace(results4.Weight.iloc[0],67)
#transforming Weight from float to integer
results4['Weight']=results4.Weight.apply(np.int64)

# %%
results4[results4.Athlete_ID.isnull()]
# Out:
#             ID                                     Name Sex  Age  Height  \
# 92100    46661                          Jean Hauptmanns   M   26     176
# 51334    26388  Luis ngel Fernando de los Santos Grossi   M   23     176
# 215056  107953      Eleonora Margarida Josephina Scmitt   F   16     176
# 215055  107953      Eleonora Margarida Josephina Scmitt   F   16     176
# 51335    26388  Luis ngel Fernando de los Santos Grossi   M   27     176
# 51336    26388  Luis ngel Fernando de los Santos Grossi   M   27     176
# 51337    26388  Luis ngel Fernando de los Santos Grossi   M   27     176
# 51338    26388  Luis ngel Fernando de los Santos Grossi   M   27     176
# 58302    29843                              Th Ngn Thng   F   19     147
# 58303    29843                              Th Ngn Thng   F   19     147
# 58304    29843                              Th Ngn Thng   F   19     147
# 58305    29843                              Th Ngn Thng   F   19     147
# ...

# %%
#these data points were dropped, because even after the use of ffill(), the data points were too ambigous
results4.drop([92100, 58301, 1560, 58307, 58308, 51338, 58306, 58305, 58304, 58303, 58302,
               51337, 51336, 51335, 51334, 215055, 215056], 0, inplace=True)
# Out:
# /var/folders/06/r72gs4510ldd1g4t75zm78vc0000gn/T/ipykernel_4326/564590031.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   results4.drop([92100, 58301, 1560, 58307, 58308, 51338, 58306, 58305, 58304, 58303, 58302, 51337, 51336, 51335, 51334, 215055, 215056], 0, inplace=True)

# %%
results4
# Out:
#             ID                      Name Sex  Age  Height  Weight  \
# 68791    35094            Angelos Fetsis   M   21     176      67
# 204735  102806             Richard Rstel   M   21     176      67
# 181753   91353  Georgios Paraskevopoulos   M   21     176      67
# 181754   91353  Georgios Paraskevopoulos   M   21     176      67
# 204736  102806             Richard Rstel   M   21     176      67
# ...        ...                       ...  ..  ...     ...     ...
# 40051    20599         Phillip Hung Chew   M   22     173      91
# 194190   97481               Bence Pulai   M   24     193      89
# 194191   97481               Bence Pulai   M   24     193      89
# 40081    20616                Danny Chia   M   43     170      75
# 245289  122828       Nigora Tursunkulova   F   17     181      67
#
#                  Team  NOC        Games  Year  ...            City  \
# 68791          Greece  GRE  1896 Summer  1896  ...          Athina
# ...

# %%
#transforming Athlete_ID from float to integer
results4['Athlete_ID']=results4.Athlete_ID.apply(np.int64)

# %%
#reindexing the columns
results5=results4.reindex(columns=['Athlete_ID', 'Sex', 'Age', 'Height', 'Weight', 'NOC_ID',
                                   'Games_ID', 'Year', 'Season_ID', 'City', 'Sport_ID', 'Medal_ID'])

# %%
#setting a new index
results5.set_index('Athlete_ID', inplace=True)

# %%
results5
# Out:
#            Sex  Age  Height  Weight  NOC_ID  Games_ID  Year  Season_ID  \
# Athlete_ID
# 8910         M   21     176      67      82         1  1896          1
# 105935       M   21     176      67      80         1  1896          1
# 40872        M   21     176      67      82         1  1896          1
# 40872        M   21     176      67      82         1  1896          1
# 105935       M   21     176      67      80         1  1896          1
# ...         ..  ...     ...     ...     ...       ...   ...        ...
# 101394       M   22     173      91     217        52  2016          1
# 14303        M   24     193      89      91        52  2016          1
# 14303        M   24     193      89      91        52  2016          1
# 24827        M   43     170      75     127        52  2016          1
# 93320        F   17     181      67     218        52  2016          1
#
#                       City  Sport_ID  Medal_ID
# Athlete_ID
# ...

# %%
#adding a new column, with unique values for every gender
results5['Sex_ID']=results5['Sex'].apply(lambda x: 1 if x=='M' else 2)

# %%
#dropping the 'Sex' column
results5.drop('Sex',1, inplace=True)
# Out:
# /var/folders/06/r72gs4510ldd1g4t75zm78vc0000gn/T/ipykernel_4326/426421636.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   results5.drop('Sex',1, inplace=True)

# %%
#saving it on a csv file
results5.to_csv('/Users/alexandergandji/Desktop/Course Folder/Capstone Project SQL Data Science /Sports/results.csv')
